# %% [markdown]
# # Excel

# %% [markdown]
# `UnstructuredExcelLoader`는 `Microsoft Excel` 파일을 로드하는 데 사용됩니다.
#
# 이 로더는 `.xlsx` 및 `.xls` 파일 모두에서 작동합니다. 페이지 내용은 Excel 파일의 원시 텍스트가 됩니다.
#
# `"elements"` 모드에서 로더를 사용하는 경우, 문서 메타데이터의 `text_as_html` 키 아래에서 Excel 파일의 HTML 표현이 제공됩니다.

# %%
# 설치
# !pip install -qU langchain-community unstructured openpyxl

# %%
from langchain_community.document_loaders import UnstructuredExcelLoader

# UnstructuredExcelLoader 생성
loader = UnstructuredExcelLoader("./data/titanic.xlsx", mode="elements")

# 문서 로드
docs = loader.load()

# 문서 길이 출력
print(len(docs))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[4], line 7
#       4 loader = UnstructuredExcelLoader("./data/titanic.xlsx", mode="elements")
#       6 # 문서 로드
# ----> 7 docs = loader.load()
#       9 # 문서 길이 출력
#      10 print(len(docs))
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/langchain_core/document_loaders/base.py:31, in BaseLoader.load(self)
#      29 def load(self) -> list[Document]:
#      30     """Load data into Document objects."""
# ---> 31     return list(self.lazy_load())
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/langchain_community/document_loaders/unstructured.py:107, in UnstructuredBaseLoader.lazy_load(self)
#     105 def lazy_load(self) -> Iterator[Document]:
#     106     """Load file."""
# --> 107     elements = self._get_elements()
#     108     self._post_process_elements(elements)
#     109     if self.mode == "elements":
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/langchain_community/document_loaders/excel.py:51, in UnstructuredExcelLoader._get_elements(self)
#      48 def _get_elements(self) -> List:
#      49     from unstructured.partition.xlsx import partition_xlsx
# ---> 51     return partition_xlsx(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/documents/elements.py:280, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     278 @functools.wraps(func)
#     279 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 280     elements = func(*args, **kwargs)
#     281     sig = inspect.signature(func)
#     282     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/file_utils/filetype.py:551, in add_metadata_with_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     549 @functools.wraps(func)
#     550 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 551     elements = func(*args, **kwargs)
#     552     sig = inspect.signature(func)
#     553     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/chunking/title.py:257, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     255 @functools.wraps(func)
#     256 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 257     elements = func(*args, **kwargs)
#     258     sig = inspect.signature(func)
#     259     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:108, in partition_xlsx(filename, file, metadata_filename, include_metadata, languages, metadata_last_modified, include_header, find_subtable, **kwargs)
#     106     elements.append(table)
#     107 else:
# --> 108     _connected_components = _get_connected_components(sheet)
#     109     for _connected_component, _min_max_coords in _connected_components:
#     110         min_x, min_y, max_x, max_y = _min_max_coords
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:224, in _get_connected_components(sheet, filter)
#     222 if (row, col) not in visited and not pd.isna(sheet.iat[row, col]):
#     223     component: List[dict] = []
# --> 224     dfs(row, col, component)
#     225     min_x, min_y, max_x, max_y = _find_min_max_coord(component)
#     226     connected_components.append(
#     227         {
#     228             "component": component,
#    (...)
#     233         },
#     234     )
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:216, in _get_connected_components.<locals>.dfs(row, col, component)
#     214 # Explore neighboring cells
#     215 dfs(row - 1, col, component)  # Above
# --> 216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#     218 dfs(row, col + 1, component)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:216, in _get_connected_components.<locals>.dfs(row, col, component)
#     214 # Explore neighboring cells
#     215 dfs(row - 1, col, component)  # Above
# --> 216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#     218 dfs(row, col + 1, component)
#
#     [... skipping similar frames: _get_connected_components.<locals>.dfs at line 216 (888 times)]
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:216, in _get_connected_components.<locals>.dfs(row, col, component)
#     214 # Explore neighboring cells
#     215 dfs(row - 1, col, component)  # Above
# --> 216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#     218 dfs(row, col + 1, component)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:218, in _get_connected_components.<locals>.dfs(row, col, component)
#     216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
# --> 218 dfs(row, col + 1, component)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:215, in _get_connected_components.<locals>.dfs(row, col, component)
#     212 component.append((row, col))
#     214 # Explore neighboring cells
# --> 215 dfs(row - 1, col, component)  # Above
#     216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:215, in _get_connected_components.<locals>.dfs(row, col, component)
#     212 component.append((row, col))
#     214 # Explore neighboring cells
# --> 215 dfs(row - 1, col, component)  # Above
#     216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#
#     [... skipping similar frames: _get_connected_components.<locals>.dfs at line 215 (888 times)]
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:215, in _get_connected_components.<locals>.dfs(row, col, component)
#     212 component.append((row, col))
#     214 # Explore neighboring cells
# --> 215 dfs(row - 1, col, component)  # Above
#     216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:218, in _get_connected_components.<locals>.dfs(row, col, component)
#     216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
# --> 218 dfs(row, col + 1, component)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:216, in _get_connected_components.<locals>.dfs(row, col, component)
#     214 # Explore neighboring cells
#     215 dfs(row - 1, col, component)  # Above
# --> 216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#     218 dfs(row, col + 1, component)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:216, in _get_connected_components.<locals>.dfs(row, col, component)
#     214 # Explore neighboring cells
#     215 dfs(row - 1, col, component)  # Above
# --> 216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#     218 dfs(row, col + 1, component)
#
#     [... skipping similar frames: _get_connected_components.<locals>.dfs at line 216 (888 times)]
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:216, in _get_connected_components.<locals>.dfs(row, col, component)
#     214 # Explore neighboring cells
#     215 dfs(row - 1, col, component)  # Above
# --> 216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#     218 dfs(row, col + 1, component)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:218, in _get_connected_components.<locals>.dfs(row, col, component)
#     216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
# --> 218 dfs(row, col + 1, component)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:215, in _get_connected_components.<locals>.dfs(row, col, component)
#     212 component.append((row, col))
#     214 # Explore neighboring cells
# --> 215 dfs(row - 1, col, component)  # Above
#     216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:215, in _get_connected_components.<locals>.dfs(row, col, component)
#     212 component.append((row, col))
#     214 # Explore neighboring cells
# --> 215 dfs(row - 1, col, component)  # Above
#     216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#
#     [... skipping similar frames: _get_connected_components.<locals>.dfs at line 215 (276 times)]
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:215, in _get_connected_components.<locals>.dfs(row, col, component)
#     212 component.append((row, col))
#     214 # Explore neighboring cells
# --> 215 dfs(row - 1, col, component)  # Above
#     216 dfs(row + 1, col, component)  # Below
#     217 dfs(row, col - 1, component)  # Left
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/unstructured/partition/xlsx.py:211, in _get_connected_components.<locals>.dfs(row, col, component)
#     208     return
#     209 visited.add((row, col))
# --> 211 if not pd.isna(sheet.iat[row, col]):
#     212     component.append((row, col))
#     214     # Explore neighboring cells
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/pandas/core/indexing.py:2527, in _ScalarAccessIndexer.__getitem__(self, key)
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
#    2526 key = self._convert_key(key)
# -> 2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/pandas/core/frame.py:4211, in DataFrame._get_value(self, index, col, takeable)
#    4192 """
#    4193 Quickly retrieve single value at passed column and index.
#    4194
#    (...)
#    4208 `self.columns._index_as_unique`; Caller is responsible for checking.
#    4209 """
#    4210 if takeable:
# -> 4211     series = self._ixs(col, axis=1)
#    4212     return series._values[index]
#    4214 series = self._get_item_cache(col)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/pandas/core/frame.py:4011, in DataFrame._ixs(self, i, axis)
#    4008 label = self.columns[i]
#    4010 col_mgr = self._mgr.iget(i)
# -> 4011 result = self._box_col_values(col_mgr, i)
#    4013 # this is a cached value, mark it so
#    4014 result._set_as_cached(label, self)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/pandas/core/frame.py:4616, in DataFrame._box_col_values(self, values, loc)
#    4614 name = self.columns[loc]
#    4615 # We get index=self.index bc values is a SingleDataManager
# -> 4616 obj = self._constructor_sliced_from_mgr(values, axes=values.axes)
#    4617 obj._name = name
#    4618 return obj.__finalize__(self)
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/pandas/core/frame.py:679, in DataFrame._constructor_sliced_from_mgr(self, mgr, axes)
#     678 def _constructor_sliced_from_mgr(self, mgr, axes) -> Series:
# --> 679     ser = Series._from_mgr(mgr, axes)
#     680     ser._name = None  # caller is responsible for setting real name
#     682     if type(self) is DataFrame:
#     683         # This would also work `if self._constructor_sliced is Series`, but
#     684         #  this check is slightly faster, benefiting the most-common case.
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/pandas/core/generic.py:357, in NDFrame._from_mgr(cls, mgr, axes)
#     342 """
#     343 Construct a new object of this type from a Manager object and axes.
#     344
#    (...)
#     354 in the event that axes are refactored out of the Manager objects.
#     355 """
#     356 obj = cls.__new__(cls)
# --> 357 NDFrame.__init__(obj, mgr)
#     358 return obj
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/pandas/core/generic.py:283, in NDFrame.__init__(self, data)
#     281 object.__setattr__(self, "_item_cache", {})
#     282 object.__setattr__(self, "_attrs", {})
# --> 283 object.__setattr__(self, "_flags", Flags(self, allows_duplicate_labels=True))
#
# File ~/anaconda3/envs/teddy/lib/python3.11/site-packages/pandas/core/flags.py:53, in Flags.__init__(self, obj, allows_duplicate_labels)
#      51 def __init__(self, obj: NDFrame, *, allows_duplicate_labels: bool) -> None:
#      52     self._allows_duplicate_labels = allows_duplicate_labels
# ---> 53     self._obj = weakref.ref(obj)
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# 1개의 문서로 로드되었음을 확인합니다.
#
# `page_content` 에는 각 행의 데이터가 저장되고, `metadata` 의 `text_as_html` 에는 각 행의 데이터를 HTML 형식으로 저장합니다.

# %%
# 문서 출력
print(docs[0].page_content[:200])

# %%
# metadata 의 text_as_html 출력
print(docs[0].metadata["text_as_html"][:1000])

# %% [markdown]
# ## DataFrameLoader
#
# - CSV 파일과 마찬가지로 Excel 파일을 로드하는 `read_excel()` 기능을 사용하여 DataFrame 으로 만든 뒤, 로드합니다.

# %%
import pandas as pd

# Excel 파일 읽기
df = pd.read_excel("./data/titanic.xlsx")

# %%
from langchain_community.document_loaders import DataFrameLoader

# 데이터 프레임 로더 설정, 페이지 내용 컬럼 지정
loader = DataFrameLoader(df, page_content_column="Name")

# 문서 로드
docs = loader.load()

# 데이터 출력
print(docs[0].page_content)

# 메타데이터 출력
print(docs[0].metadata)
